# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/shiva/Downloads/tech/cleaned_data.csv")
df
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24      2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2      85698822-43f5      90000    2          2         2   34      0      0
# 3      0737c11b-be42      50000    2          2         1   37      0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57     -1      0
# ...              ...        ...  ...        ...       ...  ...    ...    ...
# 26659  ecff42d0-bdc6     220000    1          3         1   39      0      0
# 26660  99d1fa0e-222b     150000    1          3         2   43     -1     -1
# 26661  95cdd3e7-4f24      30000    1          2         2   37      4      3
# 26662  00d03f02-04cd      80000    1          3         1   41      1     -1
# 26663  15d69f9f-5ad3      50000    1          2         1   46      0      0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df['BILL_AMT1']
# Out:
# 0          3913
# 1          2682
# 2         29239
# 3         46990
# 4          8617
#           ...
# 26659    188948
# 26660      1683
# 26661      3565
# 26662     -1645
# 26663     47929
# Name: BILL_AMT1, Length: 26664, dtype: int64

# %%
df['BILL_AMT2']
# Out:
# 0          3102
# 1          1725
# 2         14027
# 3         48233
# 4          5670
#           ...
# 26659    192815
# 26660      1828
# 26661      3356
# 26662     78379
# 26663     48905
# Name: BILL_AMT2, Length: 26664, dtype: int64

# %%
df['BILL_AMT3']
# Out:
# 0           689
# 1          2682
# 2         13559
# 3         49291
# 4         35835
#           ...
# 26659    208365
# 26660      3502
# 26661      2758
# 26662     76304
# 26663     49764
# Name: BILL_AMT3, Length: 26664, dtype: int64

# %%
df['BILL_AMT4']
# Out:
# 0            0
# 1         3272
# 2        14331
# 3        28314
# 4        20940
#          ...
# 26659    88004
# 26660     8979
# 26661    20878
# 26662    52774
# 26663    36535
# Name: BILL_AMT4, Length: 26664, dtype: int64

# %%
df['BILL_AMT5']
# Out:
# 0            0
# 1         3455
# 2        14948
# 3        28959
# 4        19146
#          ...
# 26659    31237
# 26660     5190
# 26661    20582
# 26662    11855
# 26663    32428
# Name: BILL_AMT5, Length: 26664, dtype: int64

# %%
df['BILL_AMT6']
# Out:
# 0            0
# 1         3261
# 2        15549
# 3        29547
# 4        19131
#          ...
# 26659    15980
# 26660        0
# 26661    19357
# 26662    48944
# 26663    15313
# Name: BILL_AMT6, Length: 26664, dtype: int64

# %%
df['PAY_AMT1']
# Out:
# 0            0
# 1            0
# 2         1518
# 3         2000
# 4         2000
#          ...
# 26659     8500
# 26660     1837
# 26661        0
# 26662    85900
# 26663     2078
# Name: PAY_AMT1, Length: 26664, dtype: int64

# %%
df['PAY_AMT2']
# Out:
# 0          689
# 1         1000
# 2         1500
# 3         2019
# 4        36681
#          ...
# 26659    20000
# 26660     3526
# 26661        0
# 26662     3409
# 26663     1800
# Name: PAY_AMT2, Length: 26664, dtype: int64

# %%
df['PAY_AMT3']
# Out:
# 0            0
# 1         1000
# 2         1000
# 3         1200
# 4        10000
#          ...
# 26659     5003
# 26660     8998
# 26661    22000
# 26662     1178
# 26663     1430
# Name: PAY_AMT3, Length: 26664, dtype: int64

# %%
df['PAY_AMT4']
# Out:
# 0           0
# 1        1000
# 2        1000
# 3        1100
# 4        9000
#          ...
# 26659    3047
# 26660     129
# 26661    4200
# 26662    1926
# 26663    1000
# Name: PAY_AMT4, Length: 26664, dtype: int64

# %%
df['PAY_AMT5']
# Out:
# 0            0
# 1            0
# 2         1000
# 3         1069
# 4          689
#          ...
# 26659     5000
# 26660        0
# 26661     2000
# 26662    52964
# 26663     1000
# Name: PAY_AMT5, Length: 26664, dtype: int64

# %%
df['PAY_AMT6']
# Out:
# 0           0
# 1        2000
# 2        5000
# 3        1000
# 4         679
#          ...
# 26659    1000
# 26660       0
# 26661    3100
# 26662    1804
# 26663    1000
# Name: PAY_AMT6, Length: 26664, dtype: int64

# %%
df.describe()
# Out:
#            LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count   26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean   167919.054905      1.603060      1.842334      1.556031     35.505213
# std    129839.453081      0.489272      0.744661      0.521463      9.227442
# min     10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%     50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%    140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%    240000.000000      2.000000      2.000000      2.000000     41.000000
# max    800000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# ...

# %%
df.plot('PAY_AMT4')

# %%
df.plot('PAY_AMT1')

# %%
df.plot('PAY_AMT2')

# %%
df.plot('PAY_AMT3')

# %%
df.plot('PAY_AMT5')

# %%
df.plot('PAY_AMT6')

# %%
df.plot('BILL_AMT1')

# %%
df.plot('BILL_AMT2')

# %%
df.plot('BILL_AMT3')

# %%
df.plot('BILL_AMT3')

# %%
df.plot('BILL_AMT4')

# %%
df.plot('BILL_AMT5')

# %%
df.plot('BILL_AMT6')

# %%
df.plot('BILL_AMT4')
plt.hist
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df.plot.hist()('BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6')
df=tips,palette='rainbow'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-a5ab89555f6a> in <module>
# ----> 1 df.plot.hist()('BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6')
#       2 df=tips,palette='rainbow'
#
# TypeError: 'AxesSubplot' object is not callable

# %% [markdown]
# ### ATRRITION TARGET VARIABLE

# %%
df['AGE'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        24
# 1        26
# 2        34
# 3        37
# 4        57
#          ..
# 26659    39
# 26660    43
# 26661    37
# 26662    41
# 26663    46
# Name: AGE, Length: 26664, dtype: int64>

# %% [markdown]
# # CHECKING PERCENTAGE OF NULL VALUES

# %%
Null_values_percentage=(df.isnull().sum().sum()/len(df))*100
Null_values_percentage
# Out:
# 0.0

# %%
sns.catplot(x='AGE',hue='EDUCATION',data=df,kind='count',height=15)

# %%
df['ID'].nunique()
# Out:
# 26664

# %%
id_counts = df['ID'].value_counts()
id_counts.head()
# Out:
# e4afb991-cc36    1
# 76af421a-18d5    1
# 958e1cf7-bfd5    1
# 7a4b7159-bb36    1
# 07c32b5b-4dc4    1
# Name: ID, dtype: int64

# %%
id_counts.value_counts()
# Out:
# 1    26664
# Name: ID, dtype: int64

# %% [markdown]
# # ##To begin, import data set cleaned_data.csv and create lists of feature names for the remaining financial features: 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', and 'PAY_AMT6'.
#
# Name the features bill_feats and pay_amt_feats, respectively.

# %%
# Create lists `bill_feats` and `pay_amt_feats`
bill_feats = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
pay_amt_feats = ['PAY_AMT1','PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
df[bill_feats].describe()
# Out:
#            BILL_AMT1      BILL_AMT2      BILL_AMT3      BILL_AMT4  \
# count   26664.000000   26664.000000   26664.000000   26664.000000
# mean    51405.730723   49300.001500   47026.340047   43338.894539
# std     73633.687106   70934.549534   68705.359524   64275.250740
# min   -165580.000000  -69777.000000 -157264.000000 -170000.000000
# 25%      3580.000000    2999.750000    2627.250000    2341.750000
# 50%     22361.000000   21150.000000   20079.500000   19037.000000
# 75%     67649.750000   64395.500000   60360.000000   54727.500000
# max    746814.000000  671563.000000  855086.000000  706864.000000
#
#            BILL_AMT5      BILL_AMT6
# count   26664.000000   26664.000000
# mean    40338.136701   38889.872337
# std     60705.944083   59432.541657
# min    -81334.000000 -339603.000000
# 25%      1745.000000    1256.000000
# 50%     18066.000000   17005.000000
# 75%     50290.500000   49253.750000
# max    823540.000000  699944.000000

# %% [markdown]
# ##Then you should visualize the bill amount features using a 2 by 3 grid of histogram plots.
#
# Hint: You can use 20 bins for this visualization.

# %%
plt.style.use('dark_background')

# %%
df[bill_feats].hist(bins = 20)
plt.show()

# %%
df[pay_amt_feats].describe()
# Out:
#             PAY_AMT1      PAY_AMT2       PAY_AMT3       PAY_AMT4  \
# count   26664.000000  2.666400e+04   26664.000000   26664.000000
# mean     5704.085771  5.881110e+03    5259.514964    4887.048717
# std     16699.398632  2.121431e+04   17265.439561   15956.349371
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      1000.000000  8.020000e+02     390.000000     294.750000
# 50%      2114.500000  2.007000e+03    1822.000000    1500.000000
# 75%      5027.000000  5.000000e+03    4556.250000    4050.500000
# max    873552.000000  1.227082e+06  889043.000000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   26664.000000   26664.000000
# mean     4843.729973    5257.843047
# std     15311.721795   17635.468185
# min         0.000000       0.000000
# 25%       242.750000     111.000000
# 50%      1500.000000    1500.000000
# 75%      4082.750000    4015.000000
# max    426529.000000  528666.000000

# %% [markdown]
# # ##Next, plot a histogram of the bill payment features similar to the bill amount features, but also apply some rotation to the x-axis labels with the xrot keyword argument so that they don't overlap. In any plotting function, you can include the xrot=<angle> keyword argument to rotate x-axis labels by a given angle in degrees

# %%
df[pay_amt_feats].hist(xrot = 10)
plt.show()

# %% [raw]
# ##consider thes results
# SHIVANK SHARMA
